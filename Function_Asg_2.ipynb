# %% [markdown]
# ## **Function Assg. Theory Questions**

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# - Function: Defined using def keyword and can be used independently.
# - Method: A function that is associated with an object (called using dot notation).
#
# Example:
#
# def greet():
#     return "Hello"
#
# message = "hello world"
# print(greet())         # Function
# print(message.upper()) # Method
#
#
# 2. Explain the concept of function arguments and parameters in Python.
#
# - Parameters: Variables defined in the function definition.
# - Arguments: Actual values passed when calling the function.
#
# Example:
#
# def add(a, b):   # a and b are parameters
#     return a + b
#
# print(add(5, 3)) # 5 and 3 are arguments
#
#
# 3. What are the different ways to define and call a function in Python?
#
# - User-defined function:
#
# def hello():
#     print("Hello!")
# hello()
#
#
# - Lambda function:
#
# greet = lambda name: f"Hello, {name}"
# print(greet("Shankar"))
#
#
# 4. What is the purpose of the return statement in a Python function?
#
# It sends a result back to the caller and exits the function.
#
# Example:
#
# def square(n):
#     return n * n
#
# result = square(5)
# print(result)
#
#
# 5. What are iterators in Python and how do they differ from iterables?
#
# - Iterable: An object that can return an iterator (like list, tuple, string).
# - Iterator: An object that produces one element at a time using next().
#
# Example:
#
# nums = [1, 2, 3]
# it = iter(nums)
# print(next(it))
# print(next(it))
#
#
# 6. Explain the concept of generators in Python and how they are defined.
#
# Generators use yield keyword to return values one by one.
#
# They save memory and are used for large data streams.
#
# Example:
#
# def count_up_to(n):
#     i = 1
#     while i <= n:
#         yield i
#         i += 1
#
# for num in count_up_to(3):
#     print(num)
#
#
# 7. What are the advantages of using generators over regular functions?
#
# Save memory (no full list stored in memory).
#
# Provide lazy evaluation.
#
# Improve performance for large datasets.
#
# Example:
#
# def gen_even(n):
#     for i in range(2, n+1, 2):
#         yield i
#
# print(list(gen_even(10)))
#
#
# 8. What is a lambda function in Python and when is it typically used?
#
# Anonymous (nameless) one-line function using lambda.
#
# Commonly used with map(), filter(), reduce().
#
# Example:
#
# square = lambda x: x ** 2
# print(square(5))
#
# 9. Explain the purpose and usage of the map() function in Python.
#
# map() applies a function to all elements in an iterable.
#
# Example:
#
# nums = [1, 2, 3, 4]
# squared = list(map(lambda x: x**2, nums))
# print(squared)
#
#
# 10. What is the difference between map(), reduce(), and filter() functions in Python?
#
# - Function	- Purpose	- Example
#
# - map()	- Applies a function to each item	- map(lambda x:x*2, [1,2,3]) → [2,4,6]
# - filter()	- Filters items based on a condition    - filter(lambda x:x%2==0, [1,2,3,4]) → [2,4]
# - reduce()	- Applies a function cumulatively	- reduce(lambda x,y:x+y, [1,2,3]) → 6
#
#
# 11. Internal mechanism for sum using reduce (list: [47, 11, 42, 13])
#
# - Step-by-step reduction:
#
# reduce(lambda x,y: x+y, [47, 11, 42, 13])
# = ((47 + 11) + 42) + 13
# = (58 + 42) + 13
# = 100 + 13
# = 113
#
# - Code:
#
# from functools import reduce
# nums = [47, 11, 42, 13]
# total = reduce(lambda x, y: x + y, nums)
# print(total)
